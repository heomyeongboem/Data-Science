# %% [markdown]
# #결측값 찾기
# df.isnull() 결측값있는 부분 True 반환
#
# df.isnull().sum() 각 column에 결측값의 총 갯수 반환

# %%
import pandas as pd

# %%
df = pd.read_csv("attendance.csv")
df
# Out:
#      연도     야구     축구      배구  남자농구  여자농구
# 0  2008  10881  11642  1253.0  4208  1329
# 1  2009  11562  10983  1471.0  4152  1206
# 2  2010  11402  12873     NaN  3870   705
# 3  2011  13055  10709  1774.0  3955  1445
# 4  2012  13747   7157     NaN  4537  1150
# 5  2013  11373   7656     NaN  4092  1237
# 6  2014  11429   8115  1967.0  4458  1417
# 7  2015  10357   7720  2311.0  3953  1480
# 8  2016  11583   7854  2336.0  3543  1425
# 9  2017  11668   6502  2425.0  3188  1097

# %%
df.isnull() # 결측값 있는 부분만 True 반환
# Out:
#       연도     야구     축구     배구   남자농구   여자농구
# 0  False  False  False  False  False  False
# 1  False  False  False  False  False  False
# 2  False  False  False   True  False  False
# 3  False  False  False  False  False  False
# 4  False  False  False   True  False  False
# 5  False  False  False   True  False  False
# 6  False  False  False  False  False  False
# 7  False  False  False  False  False  False
# 8  False  False  False  False  False  False
# 9  False  False  False  False  False  False

# %%
df.isnull().sum() # 각 column에 결측값이 몇개씩 있는지 보여줌
# Out:
# 연도      0
# 야구      0
# 축구      0
# 배구      3
# 남자농구    0
# 여자농구    0
# dtype: int64

# %% [markdown]
# #결측값 제거
# 결측값 있는 row 제거: df.dropna()
#
# 결측값이 있는 columns를 제거 :df.dropna(axis= 'columns')

# %%
df
# Out:
#      연도     야구     축구      배구  남자농구  여자농구
# 0  2008  10881  11642  1253.0  4208  1329
# 1  2009  11562  10983  1471.0  4152  1206
# 2  2010  11402  12873     NaN  3870   705
# 3  2011  13055  10709  1774.0  3955  1445
# 4  2012  13747   7157     NaN  4537  1150
# 5  2013  11373   7656     NaN  4092  1237
# 6  2014  11429   8115  1967.0  4458  1417
# 7  2015  10357   7720  2311.0  3953  1480
# 8  2016  11583   7854  2336.0  3543  1425
# 9  2017  11668   6502  2425.0  3188  1097

# %%
df.dropna() # 결측값이 있는 row 를 제거 
#df.dropna(inplace = True)
#df
# Out:
#      연도     야구     축구      배구  남자농구  여자농구
# 0  2008  10881  11642  1253.0  4208  1329
# 1  2009  11562  10983  1471.0  4152  1206
# 3  2011  13055  10709  1774.0  3955  1445
# 6  2014  11429   8115  1967.0  4458  1417
# 7  2015  10357   7720  2311.0  3953  1480
# 8  2016  11583   7854  2336.0  3543  1425
# 9  2017  11668   6502  2425.0  3188  1097

# %%
df.dropna(axis= 'columns') #결측값이 있는 columns를 제거 -> 배구 제거
# Out:
#      연도     야구     축구  남자농구  여자농구
# 0  2008  10881  11642  4208  1329
# 1  2009  11562  10983  4152  1206
# 2  2010  11402  12873  3870   705
# 3  2011  13055  10709  3955  1445
# 4  2012  13747   7157  4537  1150
# 5  2013  11373   7656  4092  1237
# 6  2014  11429   8115  4458  1417
# 7  2015  10357   7720  3953  1480
# 8  2016  11583   7854  3543  1425
# 9  2017  11668   6502  3188  1097

# %% [markdown]
# #결측값이 있는 부분을 채워넣음: df.fillna()
# 평균으로 대체함: df.fillna(df.mean())
#
# 중간값으로 대체함: df.fillna(df.median())

# %%
df.fillna(0) # 결측값이 있던 부분을 다 0으로 채워넣음
# Out:
#      연도     야구     축구      배구  남자농구  여자농구
# 0  2008  10881  11642  1253.0  4208  1329
# 1  2009  11562  10983  1471.0  4152  1206
# 2  2010  11402  12873     0.0  3870   705
# 3  2011  13055  10709  1774.0  3955  1445
# 4  2012  13747   7157     0.0  4537  1150
# 5  2013  11373   7656     0.0  4092  1237
# 6  2014  11429   8115  1967.0  4458  1417
# 7  2015  10357   7720  2311.0  3953  1480
# 8  2016  11583   7854  2336.0  3543  1425
# 9  2017  11668   6502  2425.0  3188  1097

# %%
df.fillna(df.mean()) #결측값을 평균으로 대체됨
# Out:
#      연도     야구     축구           배구  남자농구  여자농구
# 0  2008  10881  11642  1253.000000  4208  1329
# 1  2009  11562  10983  1471.000000  4152  1206
# 2  2010  11402  12873  1933.857143  3870   705
# 3  2011  13055  10709  1774.000000  3955  1445
# 4  2012  13747   7157  1933.857143  4537  1150
# 5  2013  11373   7656  1933.857143  4092  1237
# 6  2014  11429   8115  1967.000000  4458  1417
# 7  2015  10357   7720  2311.000000  3953  1480
# 8  2016  11583   7854  2336.000000  3543  1425
# 9  2017  11668   6502  2425.000000  3188  1097

# %%
df.fillna(df.median()) # 결측값이 중간값으로 대체됨
# Out:
#      연도     야구     축구      배구  남자농구  여자농구
# 0  2008  10881  11642  1253.0  4208  1329
# 1  2009  11562  10983  1471.0  4152  1206
# 2  2010  11402  12873  1967.0  3870   705
# 3  2011  13055  10709  1774.0  3955  1445
# 4  2012  13747   7157  1967.0  4537  1150
# 5  2013  11373   7656  1967.0  4092  1237
# 6  2014  11429   8115  1967.0  4458  1417
# 7  2015  10357   7720  2311.0  3953  1480
# 8  2016  11583   7854  2336.0  3543  1425
# 9  2017  11668   6502  2425.0  3188  1097

# %% [markdown]
# #데이터의 유일성: 중복되는 값 찾기
# row 삭제 df.drop_duplicates()

# %%
df = pd.read_csv("dust.csv")
df.head()
# Out:
#         날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  세종  경북  경남  \
# 0  08월 11일   7  17  15  10  29  12  12   9  16  14  16  25  21  11  14  24
# 1  08월 10일  15  25  15  20  28  25  17  20  16  25  29  29  25  27  14  29
# 2  08월 09일  24  26  26  27  27  27  22  27  25  32  24  24  27  26  25  38
# 3  08월 08일  26  25  28  26  29  31  20  26  29  33  26  29  31  31  28  32
# 4  08월 07일  20  26  22  25  33  24  18  23  18  23  29  33  29  27  19  28
#
#    제주  강원.1
# 0  21    16
# 1  23    16
# 2  25    25
# 3  27    29
# 4  26    18

# %%
df["날짜"].value_counts()
# Out:
# 07월 31일    2
# 08월 11일    1
# 07월 26일    1
# 07월 14일    1
# 07월 15일    1
# 07월 16일    1
# 07월 17일    1
# 07월 18일    1
# 07월 19일    1
# 07월 20일    1
# 07월 21일    1
# 07월 22일    1
# 07월 23일    1
# 07월 24일    1
# 07월 25일    1
# 07월 27일    1
# 08월 10일    1
# 07월 28일    1
# 07월 29일    1
# 07월 30일    1
# 08월 01일    1
# 08월 02일    1
# 08월 03일    1
# 08월 04일    1
# 08월 05일    1
# 08월 06일    1
# 08월 07일    1
# 08월 08일    1
# 08월 09일    1
# 07월 13일    1
# Name: 날짜, dtype: int64

# %%
df.drop_duplicates(inplace= True) # 7월 31일 삭제

# %%
df["날짜"].value_counts()

# %% [markdown]
# columns 제거
# 같은 값이 있을시 같은 행이라고 판단 -> 제거:
# df.T.drop_duplicates()

# %%
df = df.T.drop_duplicates().T

# %%
df
# Out:
#          날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  세종  경북  경남  \
# 0   08월 11일   7  17  15  10  29  12  12   9  16  14  16  25  21  11  14  24
# 1   08월 10일  15  25  15  20  28  25  17  20  16  25  29  29  25  27  14  29
# 2   08월 09일  24  26  26  27  27  27  22  27  25  32  24  24  27  26  25  38
# 3   08월 08일  26  25  28  26  29  31  20  26  29  33  26  29  31  31  28  32
# 4   08월 07일  20  26  22  25  33  24  18  23  18  23  29  33  29  27  19  28
# 5   08월 06일  31  39  29  35  27  31  31  30  22  33  28  27  30  34  29  37
# 6   08월 05일  27  36  25  31  27  24  30  27  25  31  25  26  25  25  28  31
# 7   08월 04일  27  36  26  31  27  27  32  31  39  36  30  27  27  29  29  36
# 8   08월 03일  44  32  23  47  29  28  29  44  33  31  34  27  28  32  28  31
# 9   08월 02일  40  26  20  41  26  19  20  39  25  24  33  29  22  24  22  27
# 10  08월 01일  33  26  22  40  24  18  26  35  20  26  36  30  23  28  21  25
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q1,Q3으로부터 75%지점 부터 25%지점까지의 거리 * 1.5 배에 대한 거리에 있으면  이상점이라고 판다스 박스플롯에서는 기본적으로 판단한다

# %%
# %matplotlib inline
df = pd.read_csv("beer.csv")
df.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name                    style  \
# 0           0  0.050  NaN  1436             Pub Beer      American Pale Lager
# 1           1  0.066  NaN  2265          Devil's Cup  American Pale Ale (APA)
# 2           2  0.071  NaN  2264  Rise of the Phoenix             American IPA
# 3           3  0.075  NaN  2262        Sex and Candy             American IPA
# 4           4  0.077  NaN  2261         Black Exodus            Oatmeal Stout
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
df.plot(kind = "box", y="abv")

# %%
df['abv'].describe() # 25%지점과 75%지점 찾기
# Out:
# count    2190.000000
# mean        0.060186
# std         0.117010
# min         0.032000
# 25%         0.050000
# 50%         0.055000
# 75%         0.065000
# max         5.500000
# Name: abv, dtype: float64

# %% [markdown]
# #이상점 체크후 삭제
# ## 맥주 데이터셋인데 소주면 삭제 or 도수를 잘못기입했다면 수정
# q1= df["abv"].quantile(0.25) 25%지점 값 받아오기
#
# q3= df["abv"].quantile(0.75)
#
# iqr = q3 -q1
#
# condition = (df["abv"] < q1 - iqr * 3) | (df["abv"] > q3 + iqr * 3) #이상점 위치 파악
#
# df.loc[2250,"abv"] = 0.055 #수정
#
# df.drop(df[conidition].index) #소주 삭제
#
# df.plot(kind= "box", y= "abv")

# %%
df['abv'].quantile(0.25) # 25%지점 값 받아오기
# Out:
# 0.05

# %%
df['abv'].quantile(0.75) # 75%지점 값 받아오기
# Out:
# 0.065

# %%
q1 = df['abv'].quantile(0.25)
q3 = df['abv'].quantile(0.75)
iqr = q3 - q1
condition = (df['abv'] < q1 - 1.5 * iqr )| (df["abv"] > q3 + 1.5 * iqr) #이상점 체크

# %%
df[condition] #이상점 인덱싱
# Out:
#       Unnamed: 0    abv   ibu    id                 name  \
# 963          963  0.172   NaN  3691       Chamisul Fresh
# 1856        1856  0.400   NaN  3012           Grey Goose
# 2250        2250  5.500  40.0   145  Silverback Pale Ale
#
#                         style  brewery_id  ounces
# 963                      Soju         993   12.17
# 1856                    Vodka         893   25.26
# 2250  American Pale Ale (APA)         424   12.00

# %%
df.loc[2250,"abv"] = 0.055

# %%
df.loc[2250]
condition = (df['abv'] < q1 - 1.5 * iqr )| (df["abv"] > q3 + 1.5 * iqr) #이상점 체크 
df[condition]
# Out:
#       Unnamed: 0    abv  ibu    id            name  style  brewery_id  ounces
# 963          963  0.172  NaN  3691  Chamisul Fresh   Soju         993   12.17
# 1856        1856  0.400  NaN  3012      Grey Goose  Vodka         893   25.26

# %%
df[condition].index # 이상점에 있는 값들에 대한 인덱스 체크
# Out:
# Int64Index([963, 1856], dtype='int64')

# %%
df.drop(df[condition].index, inplace = True)
#df[condition]

# %%
condition = (df['abv'] < q1 - 1.5 * iqr )| (df["abv"] > q3 + 1.5 * iqr) #이상점 체크 
df[condition] #이상점이 없는 것을 파악
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, abv, ibu, id, name, style, brewery_id, ounces]
# Index: []

# %%
df.plot(kind= "box", y= "abv")#이상점이 없는 것을 파악 box로

# %% [markdown]
# #관계적 이상점(relational Outlier)
# 두변수의 관계를 고려했을때 이상한 데이터

# %%
df = pd.read_csv("exam_outlier.csv")
df.plot(kind= "scatter",x= "reading score", y= "writing score")

# %%
df[df["writing score"] > 100] # 51번의 writing score가 이상점
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 51   male        group E          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 51               completed          77             69            680

# %%
df.drop(51,inplace =True) # drop할때는 index 번호로 삭제

# %% [markdown]
# 관계적 이상점 보임
#
# -> 조건을 통하여 확인
#
# condition = ( df["writing score"] > 80 ) & ( df["reading score"] < 40 )
#
# df[condition]
#
# df.drop(373,inplace = True)

# %%
df.plot(kind= "scatter",x= "reading score",y= "writing score")

# %%
df.corr()

# %%
condition = (df["writing score"] > 80) & (df["reading score"] < 40) # 분석에 방해됨 (관계적 이상점)

# %%
df[condition]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 373  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 373               completed          82             26             96

# %%
df.drop(373,inplace= True)

# %%
df.plot(kind ='scatter',x='reading score',y='writing score')

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817735       0.802722
# reading score    0.817735       1.000000       0.954440
# writing score    0.802722       0.954440       1.000000

# %% [markdown]
# #실습과제
#
# 영화 감독이 꿈인 래진이는 영화에 대한 데이터 분석을 해보려고 합니다.
#
# movie_metadata.csv에는 영화에 대한 제목, 감독, 배우, 평점, 예산 등의 정보가 있는데요.
#
# 과연 예산을 많이 쓰면 소비자 평점이 높아질 지 궁금합니다.
#
# 산점도를 그려봤더니, 아주 큰 예산을 쓴 영화 몇 개 때문에 상관 관계를 파악할 수가 없네요.

# %%
df = pd.read_csv("movie_metadata.csv")

# %%
df.head()
# Out:
#                                                title    year  \
# 0                                            Avatar   2009.0
# 1          Pirates of the Caribbean: At World's End   2007.0
# 2                                           Spectre   2015.0
# 3                             The Dark Knight Rises   2012.0
# 4  Star Wars: Episode VII - The Force Awakens    ...     NaN
#
#                             genres           director          actor_1  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1         Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2        Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                  Action|Thriller  Christopher Nolan        Tom Hardy
# 4                      Documentary        Doug Walker      Doug Walker
#
#             actor_2               actor_3 language country       budget  \
# 0  Joel David Moore             Wes Studi  English     USA  237000000.0
# ...

# %%
df.plot(kind ='scatter',x="budget", y= "imdb_score")

# %%
q3 = df["budget"].quantile(0.75) #df["column"].quantile(float)
q1 = df["budget"].quantile(0.25) 
IQR = q3 - q1
condition = (df["budget"] > q3 + IQR * 5 )

# %%
df[condition]

# %%
df.drop(df[condition].index,inplace =True) # df.drop(df[condition].index , inplace = True)
df

# %%
df.plot(kind= "scatter",x = "budget", y= "imdb_score") # df,plot(kind= "scatter", x= "1",y="2")

# %% [markdown]
# #실습과제
# 이번에도 예산이 너무 큰 영화 몇 개를 제거해보려고 합니다.
#
# 하지만 이번에는 IQR이 아니라 예산 상위 15개를 제거하려고 하는데요.
#
# movie_metadata.csv에서 예산이 가장 높은 15개 영화를 제거하고, 산점도를 그려보세요.

# %%
df = pd.read_csv("movie_metadata.csv")
c1 = df["budget"].sort_values(ascending = False).head(15).index
df.drop(c1,inplace = True)
df.plot(kind= "scatter", x= "budget", y= "imdb_score")
